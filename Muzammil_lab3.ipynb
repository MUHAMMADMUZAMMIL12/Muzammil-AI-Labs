# %%
# !pip install -U google-genai
from google import genai

# %%
client = genai.Client(api_key="AQ.Ab8RN6KEA2xwzAw69V5wjDgk95_joQ6FjwesOM294eBwr68BKg")

# %%
def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1.⁠ ⁠Destination Overview
2.⁠ ⁠Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3.⁠ ⁠Places to Visit (specific locations)
4.⁠ ⁠Food Suggestions (local dishes)
5.⁠ ⁠Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: Exit
# Goodbye

# %%
MODEL = "models/gemini-3.5-flash"

# %%
def job_search_agent(user_input):

    prompt = f"""
You are a professional career counselor and AI job search agent.

Provide a well-structured job search strategy with clear headings:

1. Target Roles & Industry Overview
2. Where to Apply (specific job boards, platforms, and company career portals)
3. Key Skills & Resume Keywords
4. Networking & Outreach Strategy
5. Interview Preparation & Tips

Make the response detailed, actionable, and easy for job seekers or recent graduates to follow.

User request: {user_input}

Job Search Strategy:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("AI Job Search Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = job_search_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# AI Job Search Agent Started (type 'exit' to stop)
#
# You: Exit
# Goodbye
